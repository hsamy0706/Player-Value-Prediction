# %%
import numpy as np
import pandas as pd
import  seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from scipy.stats import f_oneway
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# %pip install --upgrade category_encoders
from category_encoders import TargetEncoder
import joblib
# Out:
# Requirement already satisfied: category_encoders in c:\users\home\.conda\envs\ml\lib\site-packages (2.4.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\home\.conda\envs\ml\lib\site-packages (from category_encoders) (1.8.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\home\.conda\envs\ml\lib\site-packages (from category_encoders) (0.13.2)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\home\appdata\roaming\python\python39\site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\home\appdata\roaming\python\python39\site-packages (from category_encoders) (1.20.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\home\.conda\envs\ml\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\home\.conda\envs\ml\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\home\appdata\roaming\python\python39\site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\home\appdata\roaming\python\python39\site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: six in c:\users\home\appdata\roaming\python\python39\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\home\.conda\envs\ml\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\home\.conda\envs\ml\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\home\.conda\envs\ml\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\home\.conda\envs\ml\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->category_encoders) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Load player player_data set & print head**

# %%
player_data=pd.read_csv("player-value-prediction.csv")
player_data.head()
# Out:
#        id          name         full_name  birth_date  age  height_cm  \
# 0  210824  F. Tchenkoua  Fabien Tchenkoua   10/1/1992   26     172.72
# 1  172835  M. Andreolli   Marco Andreolli   6/10/1986   32     187.96
# 2  212223    S. Maguire      Sean Maguire    5/1/1994   24     175.26
# 3  188168     G. Friend     George Friend  10/19/1987   31     187.96
# 4  226139     J. Tamimi   Jonathan Tamimi  10/12/1994   24     175.26
#
#    weight_kgs positions          nationality  overall_rating  ...   LDM   CDM  \
# 0        73.9     LM,RM             Cameroon              64  ...  51+2  51+2
# 1        79.8        CB                Italy              72  ...  61+2  61+2
# 2        68.0     ST,LM  Republic of Ireland              71  ...  48+2  48+2
# 3        83.0    LB,LWB              England              72  ...  68+2  68+2
# 4        74.8    RWB,RM               Jordan              64  ...  58+2  58+2
#
#     RDM   RWB    LB   LCB    CB   RCB    RB      value
# 0  51+2  57+2  56+2  50+2  50+2  50+2  56+2   525000.0
# 1  61+2  54+2  58+2  71+2  71+2  71+2  58+2  1800000.0
# 2  48+2  53+2  51+2  47+2  47+2  47+2  51+2  3400000.0
# 3  68+2  70+2  70+2  70+2  70+2  70+2  70+2  2200000.0
# 4  58+2  62+2  61+2  58+2  58+2  58+2  61+2   525000.0
#
# [5 rows x 92 columns]

# %% [markdown]
# **Display some info about player_data set**

# %%
player_data.describe()
# Out:
#                   id           age     height_cm    weight_kgs  \
# count   14363.000000  14363.000000  14363.000000  14363.000000
# mean   215308.410569     25.575367    174.902069     75.304268
# std     29906.749470      4.700271     14.056556      7.085472
# min        16.000000     17.000000    152.400000     49.900000
# 25%    200913.000000     22.000000    154.940000     69.900000
# 50%    222771.000000     25.000000    175.260000     74.800000
# 75%    237607.000000     29.000000    185.420000     79.800000
# max    247607.000000     45.000000    205.740000    110.200000
#
#        overall_rating     potential           wage  \
# count    14363.000000  14363.000000   14172.000000
# mean        66.257676     71.435355    9888.371437
# std          6.958515      6.120675   21943.412002
# min         47.000000     48.000000    1000.000000
# 25%         62.000000     67.000000    1000.000000
# 50%         66.000000     71.000000    3000.000000
# 75%         71.000000     75.000000    9000.000000
# max         94.000000     95.000000  455000.000000
#
#        international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  ...  \
# count                   14363.000000    14363.000000      14363.000000  ...
# mean                        1.110701        2.946738          2.358560  ...
# std                         0.392804        0.662851          0.762557  ...
# min                         1.000000        1.000000          1.000000  ...
# 25%                         1.000000        3.000000          2.000000  ...
# 50%                         1.000000        3.000000          2.000000  ...
# 75%                         1.000000        3.000000          3.000000  ...
# max                         5.000000        5.000000          5.000000  ...
#
#           composure       marking  standing_tackle  sliding_tackle  \
# count  14363.000000  14363.000000     14363.000000    14363.000000
# mean      58.680847     47.091207        47.676460       45.678619
# std       11.628867     20.106413        21.763713       21.359824
# min       12.000000      3.000000         2.000000        4.000000
# 25%       51.000000     29.000000        26.000000       24.000000
# 50%       60.000000     52.000000        55.000000       52.000000
# 75%       67.000000     64.000000        66.000000       64.000000
# max       95.000000     94.000000        93.000000       90.000000
#
#           GK_diving  GK_handling    GK_kicking  GK_positioning   GK_reflexes  \
# count  14363.000000  14363.00000  14363.000000    14363.000000  14363.000000
# mean      16.841537     16.62111     16.431247       16.595558     16.952447
# std       17.968259     17.17393     16.761096       17.328204     18.265496
# min        1.000000      1.00000      1.000000        1.000000      1.000000
# 25%        8.000000      8.00000      8.000000        8.000000      8.000000
# 50%       11.000000     11.00000     11.000000       11.000000     11.000000
# 75%       14.000000     14.00000     14.000000       14.000000     14.000000
# max       90.000000     92.00000     91.000000       90.000000     94.000000
#
#               value
# count  1.416500e+04
# mean   2.481204e+06
# std    5.726778e+06
# min    1.000000e+04
# 25%    3.250000e+05
# 50%    7.000000e+05
# 75%    2.100000e+06
# max    1.080000e+08
#
# [8 rows x 50 columns]

# %% [markdown]
# **check nulls in player_data**

# %%
print(player_data.isnull().sum())
print(player_data.isnull().values.sum())
f, ax = plt.subplots(figsize=(50, 6))
sns.heatmap(player_data.isnull(),yticklabels=False,cbar=False,cmap="viridis",ax=ax)
# Out:
# id               0
# name             0
# full_name        0
# birth_date       0
# age              0
#               ...
# LCB           1672
# CB            1672
# RCB           1672
# RB            1672
# value          198
# Length: 92, dtype: int64
# 123044
# <AxesSubplot:>

# %%
data=player_data.copy()
data.head()
# Out:
#        id          name         full_name  birth_date  age  height_cm  \
# 0  210824  F. Tchenkoua  Fabien Tchenkoua   10/1/1992   26     172.72
# 1  172835  M. Andreolli   Marco Andreolli   6/10/1986   32     187.96
# 2  212223    S. Maguire      Sean Maguire    5/1/1994   24     175.26
# 3  188168     G. Friend     George Friend  10/19/1987   31     187.96
# 4  226139     J. Tamimi   Jonathan Tamimi  10/12/1994   24     175.26
#
#    weight_kgs positions          nationality  overall_rating  ...   LDM   CDM  \
# 0        73.9     LM,RM             Cameroon              64  ...  51+2  51+2
# 1        79.8        CB                Italy              72  ...  61+2  61+2
# 2        68.0     ST,LM  Republic of Ireland              71  ...  48+2  48+2
# 3        83.0    LB,LWB              England              72  ...  68+2  68+2
# 4        74.8    RWB,RM               Jordan              64  ...  58+2  58+2
#
#     RDM   RWB    LB   LCB    CB   RCB    RB      value
# 0  51+2  57+2  56+2  50+2  50+2  50+2  56+2   525000.0
# 1  61+2  54+2  58+2  71+2  71+2  71+2  58+2  1800000.0
# 2  48+2  53+2  51+2  47+2  47+2  47+2  51+2  3400000.0
# 3  68+2  70+2  70+2  70+2  70+2  70+2  70+2  2200000.0
# 4  58+2  62+2  61+2  58+2  58+2  58+2  61+2   525000.0
#
# [5 rows x 92 columns]

# %%
#preprocessing of traits column
player_data['traits'] = player_data['traits'].fillna("Technical Dribbler (CPU AI Only)")# fill nulls with mod

traits_text=""
for i in player_data['traits']:
    traits_text=traits_text+','
    traits_text=traits_text+str(i)

trait_list = traits_text.split(',')

unique_list = []
for x in trait_list:
    if x not in unique_list:
        unique_list.append(x)

print(len(unique_list))
# Out:
# 37

# %% [markdown]
# **Nulls** **handling**
#
# 1.   wage & value ==> replace nulls with median(found that median =null ,so i replaced it with mode)
# 2.   national_rating,contract_end_year,club_join_date ==> fill nulls with zero
#
# 1.   club_rating==> replace nulls with mean
#
#
#
#
# 4.   Drop columns['national_team','national_team_position','tags','club_team','club_position','traits','national_jersey_number','club_jersey_number'])]
# 2.   predict nulls of last 27 columns

# %%
#Drop columns
data.drop(['national_team','national_team_position','tags',
                  'club_team','club_position','traits','national_jersey_number','club_jersey_number'],axis=1, inplace=True)
#fill null with zero
data.fillna({'national_rating':0,'club_join_date':0,'contract_end_year':0},inplace=True) 



#replace nulls with mode
data['value'].fillna(player_data.value.mode()[0],inplace=True)
data['wage'].fillna(player_data.wage.mode()[0],inplace=True)
data['release_clause_euro'].fillna(player_data.release_clause_euro.mode()[0],inplace=True)
#replace nulls with mean
data['club_rating'].fillna(int(data['club_rating'].mean()),inplace=True)

#predict nulls
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors = 10, weights = 'uniform', 
metric = 'euclidean', algorithm = 'kd_tree')
df=player_data.iloc[:,65:92].dropna()
X_train=np.array(df.iloc[:,-1])
X_train = X_train.reshape(X_train.shape[0],1)
df.drop(['value'],axis=1,inplace=True)


def impute_missing_occ (row):
    if pd.isnull(row[column_name]) :
        return knn_model.predict(
            row[['value']].values.reshape((-1,1)))
    else:
        return row[[column_name]]
  
for i,column_name in enumerate(df.columns):
    y_train=np.array(df.iloc[:,i])
    y_train = y_train.reshape(y_train.shape[0],1)
    knn_model.fit(X_train, y_train)
    data[column_name]=data.apply(impute_missing_occ,axis=1) 

print("Test save knn")
print(data[column_name])

f, ax = plt.subplots(figsize=(70, 6))
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap="viridis",ax=ax)
# Out:
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Home\.conda\envs\ml\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Test save knn
# 0        56+2
# 1        58+2
# 2        51+2
# 3        70+2
# 4        61+2
#          ...
# 14358    57+2
# 14359    53+2
# 14360    73+3
# 14361    55+2
# 14362    51+2
# Name: RB, Length: 14363, dtype: object
# <AxesSubplot:>

# %%
# %pip install researchpy
import researchpy as rp

catCols = player_data.select_dtypes("object").columns
V=np.zeros([df.shape[1],df.shape[1]])
for i,column_name in enumerate(df.columns):
    v=[]
    for j,name in enumerate(df.columns): 
        ctab,chi_statistic,expected=rp.crosstab(player_data[name],player_data[column_name],margins=False,test='chi-square',expected_freqs=True)
        v.append(chi_statistic.iloc[2,1])
    V[i]=v 

categories_corr=pd.DataFrame(V,index=df.columns,columns=df.columns)   
categories_corr
# Out:
# Requirement already satisfied: researchpy in c:\users\home\.conda\envs\ml\lib\site-packages (0.3.2)
# Requirement already satisfied: patsy in c:\users\home\.conda\envs\ml\lib\site-packages (from researchpy) (0.5.2)
# Requirement already satisfied: pandas in c:\users\home\appdata\roaming\python\python39\site-packages (from researchpy) (1.2.4)
# Requirement already satisfied: numpy in c:\users\home\appdata\roaming\python\python39\site-packages (from researchpy) (1.20.3)
# Requirement already satisfied: scipy in c:\users\home\.conda\envs\ml\lib\site-packages (from researchpy) (1.8.0)
# Requirement already satisfied: statsmodels in c:\users\home\.conda\envs\ml\lib\site-packages (from researchpy) (0.13.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\home\appdata\roaming\python\python39\site-packages (from pandas->researchpy) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\home\appdata\roaming\python\python39\site-packages (from pandas->researchpy) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\home\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7.3->pandas->researchpy) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\home\.conda\envs\ml\lib\site-packages (from statsmodels->researchpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\home\.conda\envs\ml\lib\site-packages (from packaging>=21.3->statsmodels->researchpy) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.
#          LS      ST      RS      LW      LF      CF      RF      RW     LAM  \
# LS   1.0000  1.0000  1.0000  0.4722  0.5004  0.5004  0.5004  0.4722  0.4492
# ST   1.0000  1.0000  1.0000  0.4722  0.5004  0.5004  0.5004  0.4722  0.4492
# RS   1.0000  1.0000  1.0000  0.4722  0.5004  0.5004  0.5004  0.4722  0.4492
# LW   0.4722  0.4722  0.4722  1.0000  0.5777  0.5777  0.5777  1.0000  0.5501
# LF   0.5004  0.5004  0.5004  0.5777  1.0000  1.0000  1.0000  0.5777  0.5669
# CF   0.5004  0.5004  0.5004  0.5777  1.0000  1.0000  1.0000  0.5777  0.5669
# RF   0.5004  0.5004  0.5004  0.5777  1.0000  1.0000  1.0000  0.5777  0.5669
# RW   0.4722  0.4722  0.4722  1.0000  0.5777  0.5777  0.5777  1.0000  0.5501
# LAM  0.4492  0.4492  0.4492  0.5501  0.5669  0.5669  0.5669  0.5501  1.0000
# CAM  0.4492  0.4492  0.4492  0.5501  0.5669  0.5669  0.5669  0.5501  1.0000
# RAM  0.4492  0.4492  0.4492  0.5501  0.5669  0.5669  0.5669  0.5501  1.0000
# LM   0.4315  0.4315  0.4315  0.5967  0.5346  0.5346  0.5346  0.5967  0.5608
# LCM  0.3776  0.3776  0.3776  0.4230  0.4268  0.4268  0.4268  0.4230  0.4699
# CM   0.3776  0.3776  0.3776  0.4230  0.4268  0.4268  0.4268  0.4230  0.4699
# RCM  0.3776  0.3776  0.3776  0.4230  0.4268  0.4268  0.4268  0.4230  0.4699
# RM   0.4315  0.4315  0.4315  0.5967  0.5346  0.5346  0.5346  0.5967  0.5608
# LWB  0.3092  0.3092  0.3092  0.3285  0.3181  0.3181  0.3181  0.3285  0.3235
# LDM  0.3212  0.3212  0.3212  0.3148  0.3175  0.3175  0.3175  0.3148  0.3154
# CDM  0.3212  0.3212  0.3212  0.3148  0.3175  0.3175  0.3175  0.3148  0.3154
# RDM  0.3212  0.3212  0.3212  0.3148  0.3175  0.3175  0.3175  0.3148  0.3154
# RB   0.3239  ...  0.5729  0.4573  0.4573  0.4573  0.5729  1.0000  0.4127
#
#          CB     RCB      RB
# LS   0.3371  0.3371  0.3140
# ST   0.3371  0.3371  0.3140
# RS   0.3371  0.3371  0.3140
# LW   0.3228  0.3228  0.3264
# LF   0.3308  0.3308  0.3245
# CF   0.3308  0.3308  0.3245
# RF   0.3308  0.3308  0.3245
# RW   0.3228  0.3228  0.3264
# LAM  0.3314  0.3314  0.3239
# CAM  0.3314  0.3314  0.3239
# RAM  0.3314  0.3314  0.3239
# LM   0.3317  0.3317  0.3218
# LCM  0.3364  0.3364  0.3353
# CM   0.3364  0.3364  0.3353
# RCM  0.3364  0.3364  0.3353
# RM   0.3317  0.3317  0.3218
# LWB  0.3910  0.3910  0.5729
# LDM  0.4210  0.4210  0.4573
# CDM  0.4210  0.4210  0.4573
# RDM  0.4210  0.4210  0.4573
# RWB  0.3910  0.3910  0.5729
# LB   0.4127  0.4127  1.0000
# LCB  1.0000  1.0000  0.4127
# CB   1.0000  1.0000  0.4127
# RCB  1.0000  1.0000  0.4127
# RB   0.4127  0.4127  1.0000
#
# [26 rows x 26 columns]

# %% [markdown]
# **Handling categories**
#
# 1.   work_rate,body_type ==> label_encoding
# 2.  preffered_foot ==> one hot encoding
#
# 1.   positions ==> split by (,),then apply labe encoding
#
# 2.   last 27 columns ==> target encoding

# %%
# Splitting strings
data['club_join_date'] = data['club_join_date'].astype(str)
for i,cell in enumerate(data['club_join_date']):
      
        if cell=="0":
            data['club_join_date'][i]=int(0)
        else:
            data['club_join_date'][i]=int(cell.split('/')[2])    
data['club_join_date'] = data['club_join_date'].astype(int)
            


data['contract_end_year'] = data['contract_end_year'].astype(str)
for i,cell in enumerate(data['contract_end_year']):
    if cell=="0":
            data['contract_end_year'][i]=int(0)
    elif len(cell)>4:      
            data['contract_end_year'][i]=int("20"+cell.split('-')[2])
            
data['contract_end_year'] = data['contract_end_year'].astype(int)      


for i,cell in enumerate(data['contract_end_year']):
    if data['contract_end_year'][i]==0 and data['club_join_date'][i]>0:
         data['club_join_date'][i]=0
    elif data['contract_end_year'][i]>0 and data['club_join_date'][i]==0:
         data['contract_end_year'][i]=0

# subtract contract_end_year from club_join_date
years_player_club=data['contract_end_year']-data['club_join_date']
data.insert(20,'years_player_club',years_player_club)
# Drop contract_end_year & club_join_date
data.drop(['contract_end_year','club_join_date'], axis=1, inplace=True)
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_2496\4116404162.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['club_join_date'][i]=int(cell.split('/')[2])
# C:\Users\Home\AppData\Local\Temp\ipykernel_2496\4116404162.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['club_join_date'][i]=int(0)
# C:\Users\Home\AppData\Local\Temp\ipykernel_2496\4116404162.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['contract_end_year'][i]=int("20"+cell.split('-')[2])
# C:\Users\Home\AppData\Local\Temp\ipykernel_2496\4116404162.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['contract_end_year'][i]=int(0)
# C:\Users\Home\AppData\Local\Temp\ipykernel_2496\4116404162.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['contract_end_year'][i]=0

# %%
split_positions = data['positions'].str.split(',', expand = True).rename(columns = {0:"first_positions",1:"second_positions",2:"third_positions",3:"fourth_positions",})
split_positions = split_positions.fillna("0")  


# labelencoder = LabelEncoder()

# split_positions['label_first_pos'] =  labelencoder.fit_transform(split_positions['first_positions'])
# split_positions['label_second_pos'] =  labelencoder.fit_transform(split_positions['second_positions'])
# split_positions['label_third_pos'] =  labelencoder.fit_transform(split_positions['third_positions'])
# split_positions['label_fourth_pos'] =  labelencoder.fit_transform(split_positions['fourth_positions'])

# split_positions.drop('first_positions', axis=1, inplace=True)
# split_positions.drop('second_positions', axis=1, inplace=True)
# split_positions.drop('third_positions', axis=1, inplace=True)
# split_positions.drop('fourth_positions', axis=1, inplace=True)

# for i,c in enumerate(split_positions.columns):
#     data.insert(7+i,c,split_positions[c])

data.drop(['positions'],axis=1,inplace=True)

# %%
def body_type_encoding(row):
    if row[["body_type"]].values == "Lean" :
        return 1;
    elif row[["body_type"]].values == "Normal" :
        return 2;  
    elif row[["body_type"]].values == "Stocky" :
        return 3;     
    else:
        return 2;

data["body_type"]=data.apply(body_type_encoding,axis=1)  


#work rate encoding
def work_rate_encoding(row):
    if row[["work_rate"]].values == "Low/ Low" :
        return 1;
    elif row[["work_rate"]].values == "Low/ Medium" :
        return 2;  
    elif row[["work_rate"]].values == "Medium/ Medium" :
        return 3;  
    elif row[["work_rate"]].values == "Low/ High" :
        return 4;
    elif row[["work_rate"]].values == "Medium/ Low" :
        return 5;
    elif row[["work_rate"]].values == "Medium/ High" :
        return 6;
    elif row[["work_rate"]].values == "High/ Low" :
        return 7;
    elif row[["work_rate"]].values == "High/ Medium" :
        return 8;
    elif row[["work_rate"]].values == "High/ High" :
        return 9;                           
    else:
        return 3;

data["work_rate"]=data.apply(work_rate_encoding,axis=1)


#one hot encoding
data['preferred_foot'].unique()
one_hot_encoder = OneHotEncoder()
preferred_foot_array = one_hot_encoder.fit_transform(data[['preferred_foot']]).toarray()
preferred_foot_labels = np.array(one_hot_encoder.categories_).ravel()#to make it an array, and .ravel() to convert it from array of arrays to array of strings
preferred_foot = pd.DataFrame(preferred_foot_array, columns=preferred_foot_labels)
v=data['value']
data.drop(['value','preferred_foot'],axis=1,inplace=True)
data = pd.concat([data, preferred_foot], axis = 1)
data = pd.concat([data, v], axis = 1)

#target encoding
X=player_data.iloc[:,65:91]


for i,c in enumerate(X.columns):
    encoder=TargetEncoder()
    data[c]=encoder.fit_transform(data[c],data['value'].astype('int'))
    
    

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14363 entries, 0 to 14362
# Data columns (total 83 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             14363 non-null  int64
#  1   name                           14363 non-null  object
#  2   full_name                      14363 non-null  object
#  3   birth_date                     14363 non-null  object
#  4   age                            14363 non-null  int64
#  5   height_cm                      14363 non-null  float64
#  6   weight_kgs                     14363 non-null  float64
#  7   nationality                    14363 non-null  object
#  8   overall_rating                 14363 non-null  int64
#  9   potential                      14363 non-null  int64
#  10  wage                           14363 non-null  float64
#  11  international_reputation(1-5)  14363 non-null  int64
#  12  weak_foot(1-5)                 14363 non-null  int64
#  13  skill_moves(1-5)               14363 non-null  int64
#  14  work_rate                      14363 non-null  int64
#  15  body_type                      14363 non-null  int64
#  16  release_clause_euro            14363 non-null  float64
#  17  club_rating                    14363 non-null  float64
#  18  years_player_club              14363 non-null  int32
#  19  national_rating                14363 non-null  float64
#  20  crossing                       14363 non-null  int64
#  21  finishing                      14363 non-null  int64
#  22  heading_accuracy               14363 non-null  int64
#  23  short_passing                  14363 non-null  int64
#  24  volleys                        14363 non-null  int64
#  25  dribbling                      14363 non-null  int64
#  26  curve                          14363 non-null  int64
#  27  freekick_accuracy              14363 non-null  int64
#  28  long_passing                   14363 non-null  int64
#  29  ball_control                   14363 non-null  int64
#  30  acceleration                   14363 non-null  int64
#  31  sprint_speed                   14363 non-null  int64
#  32  agility                        14363 non-null  int64
#  33  reactions                      14363 non-null  int64
#  34  balance                        14363 non-null  int64
#  35  shot_power                     14363 non-null  int64
#  36  jumping                        14363 non-null  int64
#  37  stamina                        14363 non-null  int64
#  38  strength                       14363 non-null  int64
#  39  long_shots                     14363 non-null  int64
#  40  aggression                     14363 non-null  int64
#  41  interceptions                  14363 non-null  int64
#  42  positioning                    14363 non-null  int64
#  43  vision                         14363 non-null  int64
#  44  penalties                      14363 non-null  int64
#  45  composure                      14363 non-null  int64
#  46  marking                        14363 non-null  int64
#  47  standing_tackle                14363 non-null  int64
#  48  sliding_tackle                 14363 non-null  int64
#  49  GK_diving                      14363 non-null  int64
#  50  GK_handling                    14363 non-null  int64
#  51  GK_kicking                     14363 non-null  int64
#  52  GK_positioning                 14363 non-null  int64
#  53  GK_reflexes                    14363 non-null  int64
#  54  LS                             14363 non-null  float64
#  55  ST                             14363 non-null  float64
#  56  RS                             14363 non-null  float64
#  57  LW                             14363 non-null  float64
#  58  LF                             14363 non-null  float64
#  59  CF                             14363 non-null  float64
#  60  RF                             14363 non-null  float64
#  61  RW                             14363 non-null  float64
#  62  LAM                            14363 non-null  float64
#  63  CAM                            14363 non-null  float64
#  64  RAM                            14363 non-null  float64
#  65  LM                             14363 non-null  float64
#  66  LCM                            14363 non-null  float64
#  67  CM                             14363 non-null  float64
#  68  RCM                            14363 non-null  float64
#  69  RM                             14363 non-null  float64
#  70  LWB                            14363 non-null  float64
#  71  LDM                            14363 non-null  float64
#  72  CDM                            14363 non-null  float64
#  73  RDM                            14363 non-null  float64
#  74  RWB                            14363 non-null  float64
#  75  LB                             14363 non-null  float64
#  76  LCB                            14363 non-null  float64
#  77  CB                             14363 non-null  float64
#  78  RCB                            14363 non-null  float64
#  79  RB                             14363 non-null  float64
#  80  Left                           14363 non-null  float64
#  81  Right                          14363 non-null  float64
#  82  value                          14363 non-null  float64
# dtypes: float64(35), int32(1), int64(43), object(4)
# memory usage: 9.0+ MB

# %% [markdown]
# **Extract important features**

# %%
pd.set_option('display.max_columns', 500)
player_data.corr()
# Out:
#                                      id       age  height_cm  weight_kgs  \
# id                             1.000000 -0.745924  -0.066921   -0.194347
# age                           -0.745924  1.000000   0.063121    0.232562
# height_cm                     -0.066921  0.063121   1.000000    0.496268
# weight_kgs                    -0.194347  0.232562   0.496268    1.000000
# overall_rating                -0.421744  0.461709   0.038438    0.153005
# weak_foot(1-5)                       0.216293   0.167125  0.142333
# skill_moves(1-5)                     0.419611   0.354497  0.267703
# release_clause_euro                  0.613272   0.582766  0.854397
# club_rating                          0.609519   0.677349  0.547299
# club_jersey_number                  -0.209501   0.002739 -0.086565
# national_rating                      0.729790   0.653627  0.537949
# national_jersey_number              -0.132585  -0.043588 -0.140749
# crossing                             0.399154   0.241748  0.237160
# finishing                            0.340685   0.243578  0.220332
# heading_accuracy                     0.349463   0.205230  0.196279
# short_passing                        0.506701   0.369353  0.302481
# volleys                              0.392195   0.252195  0.258168
# dribbling                            0.378505   0.313695  0.239644
# curve                                0.423787   0.277206  0.265131
# freekick_accuracy                    0.400532   0.229885  0.241888
# long_passing                         0.491276   0.324677  0.287182
# ball_control                         0.463719   0.349032  0.281252
# acceleration                         0.205539   0.238242  0.129321
# sprint_speed                         0.218550   0.242878  0.134123
# agility                              0.275740   0.225721  0.161703
# reactions                            0.855760   0.504201  0.505920
# balance                              0.114452   0.139371  0.093461
# shot_power                           0.445206   0.287785  0.263111
# jumping                              0.275371   0.113608  0.144519
# stamina                              0.369579   0.202100  0.189501
# strength                             0.367066   0.086110  0.154837
# long_shots                           0.428477   0.264166  0.253906
# aggression                           0.400268   0.173272  0.206635
# interceptions                        0.326411   0.156401  0.168624
# positioning                          0.360429   0.245492  0.230648
# vision                               0.505895   0.347208  0.322163
# penalties                            0.351707   0.225618  0.230118
# composure                            0.729078   0.434636  0.428173
# marking                              0.297122   0.167049  0.157407
# standing_tackle                      0.256949   0.147443  0.135710
# sliding_tackle                       0.229021   0.134846  0.121637
# GK_diving                           -0.032334  -0.060195 -0.029765
# GK_handling                         -0.032872  -0.062007 -0.030017
# GK_kicking                          -0.037058  -0.066899 -0.032902
# GK_positioning                      -0.024434  -0.059544 -0.030790
# GK_reflexes                         -0.031816  -0.061874 -0.031959
# value                                0.628308   0.574187  0.855451
#
#                                international_reputation(1-5)  weak_foot(1-5)  \
# id                                                 -0.358141       -0.073509
# age                                                 0.256339        0.059249
# height_cm                                           0.027580       -0.130777
# weight_kgs                                          0.090888       -0.129177
# overall_rating                                      0.487549        0.216293
# potential                                           0.359194        0.167125
# wage                                                0.673709        0.142333
# international_reputation(1-5)                       1.000000        0.119987
# weak_foot(1-5)                                      0.119987        1.000000
# skill_moves(1-5)                                    0.200814        0.347037
# release_clause_euro                                 0.636101        0.157387
# club_rating                                         0.416340        0.106817
# club_jersey_number                                 -0.066215       -0.033870
# national_rating                                     0.526959        0.102483
# national_jersey_number                             -0.150557        0.085834
# crossing                                            0.186021        0.311488
# finishing                                           0.174000        0.370886
# heading_accuracy                                    0.158767        0.194870
# short_passing                                       0.236879        0.327470
# volleys                                             0.238199        0.364206
# dribbling                                           0.174108        0.358856
# curve                                               0.227273        0.350477
# freekick_accuracy                                   0.217333        0.334060
# long_passing                                        0.234655        0.283489
# ball_control                                        0.211959        0.360702
# acceleration                                        0.044930        0.272266
# sprint_speed                                        0.045287        0.261232
# agility                                             0.100286        0.306946
# reactions                                           0.437262        0.201248
# balance                                             0.050356        0.255663
# shot_power                                          0.223391        0.341236
# jumping                                             0.130035        0.077480
# stamina                                             0.093582        0.247088
# strength                                            0.139919       -0.000375
# long_shots                                          0.209731        0.366579
# aggression                                          0.176472        0.138369
# interceptions                                       0.129945        0.057442
# positioning                                         0.176137        0.356067
# vision                                              0.276776        0.341330
# penalties                                           0.217517        0.338545
# composure                                           0.383202        0.283029
# marking                                             0.118470        0.067179
# standing_tackle                                     0.092715        0.045299
# sliding_tackle                                      0.080547        0.028313
# GK_diving                                           0.001825       -0.240239
# GK_handling                                         0.001284       -0.241911
# GK_kicking                                         -0.002429       -0.238251
# GK_positioning                                      0.003714       -0.238978
# GK_reflexes                                         0.000782       -0.242093
# value                                               0.647245        0.165213
#
#                                skill_moves(1-5)  release_clause_euro  \
# id                                    -0.060315            -0.125811
# age                                    0.032653             0.063743
# height_cm                             -0.322765             0.008952
# weight_kgs                            -0.352437             0.039893
# overall_rating                         0.419611             0.613272
# potential                              0.354497             0.582766
# wage                                   0.267703             0.854397
# international_reputation(1-5)          0.200814             0.636101
# weak_foot(1-5)                         0.347037             0.157387
# skill_moves(1-5)                       1.000000             0.312368
# release_clause_euro                    0.312368             1.000000
# club_rating                            0.244064             0.536012
# club_jersey_number                    -0.032741            -0.091428
# national_rating                        0.160028             0.587566
# national_jersey_number                 0.144512            -0.113148
# crossing                               0.748775             0.242317
# finishing                              0.749231             0.251318
# heading_accuracy                       0.459975             0.182659
# short_passing                          0.737997             0.320209
# volleys                                0.749897             0.274680
# dribbling                              0.843380             0.264743
# curve                                  0.777240             0.278307
# freekick_accuracy                      0.706529             0.257280
# long_passing                           0.630809             0.300225
# ball_control                           0.822938             0.299408
# acceleration                           0.663893             0.172651
# sprint_speed                           0.637395             0.174745
# agility                                0.688551             0.194575
# reactions                              0.387373             0.533199
# balance                                0.585886             0.117536
# shot_power                             0.725725             0.271074
# jumping                                0.117326             0.132044
# stamina                                0.589967             0.211593
# strength                              -0.023170             0.136089
# long_shots                             0.758311             0.272625
# aggression                             0.367960             0.186032
# interceptions                          0.227570             0.147297
# positioning                            0.788500             0.253080
# vision                                 0.678796             0.353282
# penalties                              0.698196             0.235730
# composure                              0.599522             0.439805
# marking                                0.261297             0.139041
# standing_tackle                        0.229518             0.117352
# sliding_tackle                         0.199411             0.098060
# GK_diving                             -0.629481            -0.026977
# GK_handling                           -0.629454            -0.028872
# GK_kicking                            -0.625947            -0.030143
# GK_positioning                        -0.627040            -0.027136
# GK_reflexes                           -0.631346            -0.029748
# value                                  0.318331             0.994198
#
#                                club_rating  club_jersey_number  \
# id                               -0.092799            0.179393
# age                               0.026373           -0.240699
# height_cm                         0.035924           -0.024207
# weight_kgs                        0.065660           -0.083759
# overall_rating                    0.609519           -0.209501
# potential                         0.677349            0.002739
# wage                              0.547299           -0.086565
# international_reputation(1-5)     0.416340           -0.066215
# weak_foot(1-5)                    0.106817           -0.033870
# skill_moves(1-5)                  0.244064           -0.032741
# release_clause_euro               0.536012           -0.091428
# club_rating                       1.000000            0.060404
# club_jersey_number                0.060404            1.000000
# national_rating                   0.610573           -0.056792
# national_jersey_number           -0.071310            0.070043
# crossing                          0.197991           -0.082580
# finishing                         0.152143           -0.008782
# heading_accuracy                  0.166693           -0.089259
# short_passing                     0.284043           -0.100266
# volleys                           0.193060           -0.028466
# dribbling                         0.206530           -0.032500
# curve                             0.215192           -0.060969
# freekick_accuracy                 0.178877           -0.071572
# long_passing                      0.264250           -0.118249
# ball_control                      0.246647           -0.075865
# acceleration                      0.090758           -0.006894
# sprint_speed                      0.094787           -0.014312
# agility                           0.109789           -0.040149
# reactions                         0.512448           -0.186054
# balance                           0.041813           -0.002792
# shot_power                        0.222803           -0.052579
# jumping                           0.102363           -0.110222
# stamina                           0.095841           -0.124426
# strength                          0.109731           -0.148875
# long_shots                        0.195517           -0.050611
# aggression                        0.169706           -0.142247
# interceptions                     0.169193           -0.156142
# positioning                       0.165142           -0.025121
# vision                            0.271161           -0.075859
# penalties                         0.170405           -0.031738
# composure                         0.390159           -0.162527
# marking                           0.155521           -0.144897
# standing_tackle                   0.146656           -0.130320
# sliding_tackle                    0.140617           -0.121486
# GK_diving                         0.028635            0.004344
# GK_handling                       0.028320            0.002400
# GK_kicking                        0.023657            0.002224
# GK_positioning                    0.030666           -0.000913
# GK_reflexes                       0.028827            0.006291
# value                             0.535807           -0.091509
#
#                                national_rating  national_jersey_number  \
# id                                   -0.121907                0.120952
# age                                   0.034718               -0.134170
# height_cm                             0.105210               -0.079945
# weight_kgs                            0.082773               -0.099245
# overall_rating                        0.729790               -0.132585
# potential                             0.653627               -0.043588
# wage                                  0.537949               -0.140749
# international_reputation(1-5)         0.526959               -0.150557
# weak_foot(1-5)                        0.102483                0.085834
# skill_moves(1-5)                      0.160028                0.144512
# release_clause_euro                   0.587566               -0.113148
# club_rating                           0.610573               -0.071310
# club_jersey_number                   -0.056792                0.070043
# national_rating                       1.000000               -0.059607
# national_jersey_number               -0.059607                1.000000
# crossing                              0.175084                0.116537
# finishing                             0.123224                0.169750
# heading_accuracy                      0.170786               -0.041774
# short_passing                         0.304775                0.074964
# volleys                               0.169014                0.126988
# dribbling                             0.177127                0.151057
# curve                                 0.197319                0.141880
# freekick_accuracy                     0.190856                0.118607
# long_passing                          0.297411                0.034459
# ball_control                          0.239691                0.097023
# acceleration                          0.072951                0.169699
# sprint_speed                          0.108944                0.141574
# agility                               0.069689                0.139214
# reactions                             0.650954               -0.079975
# balance                               0.013923                0.122681
# shot_power                            0.181184                0.108606
# jumping                               0.122208               -0.096095
# stamina                               0.152265                0.072090
# strength                              0.147325               -0.071136
# long_shots                            0.170690                0.151555
# aggression                            0.124064               -0.017901
# interceptions                         0.162907               -0.061238
# positioning                           0.153204                0.150006
# vision                                0.322255                0.123331
# penalties                             0.193689                0.080196
# composure                             0.474160               -0.014947
# marking                               0.150395               -0.068173
# standing_tackle                       0.128394               -0.059912
# sliding_tackle                        0.122457               -0.062660
# GK_diving                             0.004069               -0.103960
# GK_handling                           0.007328               -0.110322
# GK_kicking                            0.009551               -0.122334
# GK_positioning                        0.008270               -0.112888
# GK_reflexes                          -0.003388               -0.100907
# value                                 0.582582               -0.106326
#
#                                crossing  finishing  heading_accuracy  \
# id                            -0.129660  -0.087330         -0.112121
# age                            0.135044   0.077688          0.152053
# height_cm                     -0.391016  -0.297575         -0.046427
# weight_kgs                    -0.395497  -0.294768          0.022951
# overall_rating                 0.399154   0.340685          0.349463
# potential                      0.241748   0.243578          0.205230
# wage                           0.237160   0.220332          0.196279
# international_reputation(1-5)  0.186021   0.174000          0.158767
# weak_foot(1-5)                 0.311488   0.370886          0.194870
# skill_moves(1-5)               0.748775   0.749231          0.459975
# release_clause_euro            0.242317   0.251318          0.182659
# club_rating                    0.197991   0.152143          0.166693
# club_jersey_number            -0.082580  -0.008782         -0.089259
# national_rating                0.175084   0.123224          0.170786
# national_jersey_number         0.116537   0.169750         -0.041774
# crossing                       1.000000   0.664458          0.489033
# finishing                      0.664458   1.000000          0.483930
# heading_accuracy               0.489033   0.483930          1.000000
# short_passing                  0.813732   0.671887          0.655849
# volleys                        0.695219   0.886855          0.518571
# dribbling                      0.861412   0.827712          0.568463
# curve                          0.837460   0.764390          0.455850
# freekick_accuracy              0.762538   0.706454          0.422599
# long_passing                   0.761185   0.525621          0.531788
# ball_control                   0.846441   0.793782          0.673550
# acceleration                   0.681554   0.619382          0.360440
# sprint_speed                   0.658661   0.605085          0.408527
# agility                        0.704361   0.652697          0.285600
# reactions                      0.398319   0.340245          0.338357
# balance                        0.626642   0.534224          0.192404
# shot_power                     0.713512   0.820901          0.619137
# jumping                        0.150532   0.110099          0.392085
# stamina                        0.691415   0.534023          0.651701
# strength                      -0.013145   0.004453          0.489971
# long_shots                     0.748857   0.880776          0.520358
# aggression                     0.493036   0.268649          0.708987
# interceptions                  0.444055   0.000989          0.561881
# positioning                    0.792522   0.890023          0.548487
# vision                         0.687954   0.704820          0.293469
# penalties                      0.654992   0.840573          0.564476
# composure                      0.588065   0.548558          0.526876
# marking                        0.463299   0.046738          0.596944
# standing_tackle                0.444515  -0.010770          0.573630
# sliding_tackle                 0.427843  -0.047173          0.548260
# GK_diving                     -0.674405  -0.596976         -0.758208
# GK_handling                   -0.672657  -0.596522         -0.756180
# GK_kicking                    -0.671151  -0.590509         -0.754469
# GK_positioning                -0.671881  -0.592971         -0.751747
# GK_reflexes                   -0.674769  -0.596141         -0.756509
# value                          0.249318   0.258215          0.186617
#
#                                short_passing   volleys  dribbling     curve  \
# id                                 -0.136442 -0.160192  -0.031815 -0.166640
# age                                 0.135833  0.145899   0.018161  0.147600
# height_cm                          -0.292246 -0.279969  -0.382790 -0.344481
# weight_kgs                         -0.291502 -0.263154  -0.412048 -0.345230
# overall_rating                      0.506701  0.392195   0.378505  0.423787
# potential                           0.369353  0.252195   0.313695  0.277206
# wage                                0.302481  0.258168   0.239644  0.265131
# international_reputation(1-5)       0.236879  0.238199   0.174108  0.227273
# weak_foot(1-5)                      0.327470  0.364206   0.358856  0.350477
# crossing                                0.762538      0.761185      0.846441
# finishing                               0.706454      0.525621      0.793782
# heading_accuracy                        0.422599      0.531788      0.673550
# short_passing                           0.738648      0.898970      0.916126
# volleys                                 0.753388      0.577350      0.798260
# dribbling                               0.757453      0.730157      0.941389
# curve                                   0.861783      0.717684      0.834215
# freekick_accuracy                       1.000000      0.706785      0.764949
# long_passing                            0.706785      1.000000      0.797866
# ball_control                            0.764949      0.797866      1.000000
# acceleration                            0.511603      0.460556      0.692596
# sprint_speed                            0.480564      0.445910      0.681752
# agility                                 0.596344      0.530957      0.713001
# reactions                               0.400991      0.472654      0.451827
# balance                                 0.526754      0.470796      0.609820
# shot_power                              0.761340      0.682555      0.835454
# jumping                                 0.090986      0.169827      0.215627
# stamina                                 0.554062      0.650984      0.748008
# strength                               -0.002560      0.134432      0.105482
# long_shots                              0.807574      0.677835      0.839731
# aggression                              0.410466      0.604495      0.570011
# interceptions                           0.304275      0.607444      0.435906
# positioning                             0.737600      0.627437      0.870347
# vision                                  0.718973      0.701675      0.721025
# penalties                               0.740425      0.555808      0.776064
# composure                               0.591720      0.660938      0.688546
# marking                                 0.310847      0.602874      0.471879
# standing_tackle                         0.288904      0.598619      0.435459
# sliding_tackle                          0.258821      0.574603      0.404714
# GK_diving                              -0.563173     -0.607436     -0.795784
# GK_handling                            -0.561842     -0.606049     -0.794989
# GK_kicking                             -0.558406     -0.602985     -0.791216
# GK_positioning                         -0.560953     -0.603305     -0.791403
# GK_reflexes                            -0.563051     -0.607370     -0.796539
# value                                   0.266355      0.305761      0.307369
#
#                                acceleration  sprint_speed   agility  \
# id                                 0.133069      0.134029 -0.019325
# age                               -0.147738     -0.145029 -0.011918
# height_cm                         -0.412083     -0.356201 -0.441228
# weight_kgs                        -0.483002     -0.416904 -0.533783
# overall_rating                     0.205539      0.218550  0.275740
# potential                          0.238242      0.242878  0.225721
# wage                               0.129321      0.134123  0.161703
# international_reputation(1-5)      0.044930      0.045287  0.100286
# weak_foot(1-5)                     0.272266      0.261232  0.306946
# skill_moves(1-5)                   0.663893      0.637395  0.688551
# release_clause_euro                0.172651      0.174745  0.194575
# club_rating                        0.090758      0.094787  0.109789
# club_jersey_number                -0.006894     -0.014312 -0.040149
# national_rating                    0.072951      0.108944  0.069689
# national_jersey_number             0.169699      0.141574  0.139214
# crossing                           0.681554      0.658661  0.704361
# finishing                          0.619382      0.605085  0.652697
# heading_accuracy                   0.360440      0.408527  0.285600
# short_passing                      0.585694      0.576686  0.623046
# volleys                            0.585311      0.570022  0.631858
# dribbling                          0.763208      0.741554  0.770762
# curve                              0.619304      0.590751  0.686439
# freekick_accuracy                  0.511603      0.480564  0.596344
# long_passing                       0.460556      0.445910  0.530957
# ball_control                       0.692596      0.681752  0.713001
# acceleration                       1.000000      0.927409  0.818615
# sprint_speed                       0.927409      1.000000  0.773386
# agility                            0.818615      0.773386  1.000000
# reactions                          0.202414      0.204935  0.290192
# balance                            0.719048      0.655737  0.776415
# shot_power                         0.555810      0.558474  0.585640
# jumping                            0.231828      0.248314  0.230098
# GK_diving                     -0.720161 -0.115286   -0.620318   -0.591955
# GK_handling                   -0.717850 -0.114407   -0.619537   -0.591277
# GK_kicking                    -0.715167 -0.115862   -0.614421   -0.590519
# GK_positioning                -0.714803 -0.107505   -0.615372   -0.587294
# GK_reflexes                   -0.719930 -0.112060   -0.618930   -0.591659
# value                          0.217627  0.141402    0.282767    0.189271
#
#                                interceptions  positioning    vision  \
# id                                 -0.159440    -0.087635 -0.212436
# age                                 0.198532     0.085815  0.193465
# height_cm                          -0.080529    -0.356700 -0.286658
# weight_kgs                         -0.038495    -0.358275 -0.279520
# overall_rating                      0.326411     0.360429  0.505895
# potential                           0.156401     0.245492  0.347208
# wage                                0.168624     0.230648  0.322163
# international_reputation(1-5)       0.129945     0.176137  0.276776
# weak_foot(1-5)                      0.057442     0.356067  0.341330
# skill_moves(1-5)                    0.227570     0.788500  0.678796
# release_clause_euro                 0.147297     0.253080  0.353282
# club_rating                         0.169193     0.165142  0.271161
# club_jersey_number                 -0.156142    -0.025121 -0.075859
# national_rating                     0.162907     0.153204  0.322255
# national_jersey_number             -0.061238     0.150006  0.123331
# crossing                            0.444055     0.792522  0.687954
# finishing                           0.000989     0.890023  0.704820
# heading_accuracy                    0.561881     0.548487  0.293469
# short_passing                       0.553848     0.768292  0.716621
# volleys                             0.102433     0.851998  0.702813
# dribbling                           0.317572     0.902914  0.731778
# curve                               0.290047     0.816767  0.748238
# freekick_accuracy                   0.304275     0.737600  0.718973
# long_passing                        0.607444     0.627437  0.701675
# ball_control                        0.435906     0.870347  0.721025
# acceleration                        0.179266     0.699507  0.472601
# sprint_speed                        0.191171     0.682035  0.441511
# agility                             0.159911     0.716056  0.601722
# reactions                           0.349509     0.391864  0.511416
# balance                             0.170958     0.606415  0.495294
# shot_power                          0.280678     0.814044  0.687829
# jumping                             0.297823     0.159211  0.075793
# stamina                             0.587187     0.662457  0.488894
# strength                            0.357704     0.018873 -0.022914
# long_shots                          0.213185     0.863955  0.757954
# aggression                          0.755884     0.408758  0.318010
# interceptions                       1.000000     0.193039  0.195569
# positioning                         0.193039     1.000000  0.740491
# vision                              0.195569     0.740491  1.000000
# penalties                           0.128729     0.807304  0.640269
# composure                           0.413477     0.593378  0.645046
# marking                             0.895687     0.226401  0.194052
# standing_tackle                     0.943039     0.181509  0.160076
# sliding_tackle                      0.930057     0.150374  0.127915
# GK_diving                          -0.497032    -0.691487 -0.391047
# GK_handling                        -0.496813    -0.690037 -0.388309
# GK_kicking                         -0.498205    -0.685551 -0.383887
# GK_positioning                     -0.492543    -0.687308 -0.386292
# GK_reflexes                        -0.497615    -0.691111 -0.391424
# value                               0.144579     0.261171  0.362123
#
#                                penalties  composure   marking  \
# id                             -0.147834  -0.385195 -0.116366
# age                             0.149895   0.394404  0.147563
# height_cm                      -0.270648  -0.111496 -0.090634
# weight_kgs                     -0.251592  -0.044247 -0.059815
# overall_rating                  0.351707   0.729078  0.297122
# potential                       0.225618   0.434636  0.167049
# wage                            0.230118   0.428173  0.157407
# international_reputation(1-5)   0.217517   0.383202  0.118470
# weak_foot(1-5)                  0.338545   0.283029  0.067179
# skill_moves(1-5)                0.698196   0.599522  0.261297
# release_clause_euro             0.235730   0.439805  0.139041
# club_rating                     0.170405   0.390159  0.155521
# club_jersey_number             -0.031738  -0.162527 -0.144897
# national_rating                 0.193689   0.474160  0.150395
# national_jersey_number          0.080196  -0.014947 -0.068173
# crossing                        0.654992   0.588065  0.463299
# finishing                       0.840573   0.548558  0.046738
# heading_accuracy                0.564476   0.526876  0.596944
# short_passing                   0.685520   0.699572  0.573632
# volleys                         0.833474   0.601711  0.137870
# dribbling                       0.773408   0.612452  0.357618
# curve                           0.756557   0.626854  0.308782
# freekick_accuracy               0.740425   0.591720  0.310847
# long_passing                    0.555808   0.660938  0.602874
# ball_control                    0.776064   0.688546  0.471879
# acceleration                    0.548586   0.370393  0.222530
# sprint_speed                    0.535277   0.374298  0.238263
# agility                         0.574852   0.451764  0.190458
# reactions                       0.354920   0.691170  0.299969
# balance                         0.491434   0.331981  0.199991
# shot_power                      0.799178   0.642742  0.313546
# jumping                         0.149353   0.266086  0.291761
# stamina                         0.537379   0.543155  0.602266
# strength                        0.074015   0.295137  0.340535
# long_shots                      0.815057   0.628292  0.237158
# aggression                      0.359257   0.533046  0.731317
# interceptions                   0.128729   0.413477  0.895687
# positioning                     0.807304   0.593378  0.226401
# vision                          0.640269   0.645046  0.194052
# penalties                       1.000000   0.568273  0.170523
# composure                       0.568273   1.000000  0.407204
# marking                         0.170523   0.407204  1.000000
# standing_tackle                 0.119752   0.367660  0.911648
# sliding_tackle                  0.086446   0.334340  0.901281
# GK_diving                      -0.626277  -0.398604 -0.561245
# GK_handling                    -0.625767  -0.396849 -0.561508
# GK_kicking                     -0.620169  -0.395709 -0.561162
# GK_positioning                 -0.623162  -0.389973 -0.557115
# GK_reflexes                    -0.624938  -0.398835 -0.561445
# value                           0.243880   0.453408  0.138631
#
#                                standing_tackle  sliding_tackle  GK_diving  \
# id                                   -0.083340       -0.066150  -0.104065
# age                                   0.117122        0.101341   0.099225
# height_cm                            -0.083005       -0.087522   0.298387
# weight_kgs                           -0.061076       -0.071301   0.346236
# overall_rating                        0.256949        0.229021  -0.032334
# potential                             0.147443        0.134846  -0.060195
# wage                                  0.135710        0.121637  -0.029765
# international_reputation(1-5)         0.092715        0.080547   0.001825
# weak_foot(1-5)                        0.045299        0.028313  -0.240239
# skill_moves(1-5)                      0.229518        0.199411  -0.629481
# release_clause_euro                   0.117352        0.098060  -0.026977
# club_rating                           0.146656        0.140617   0.028635
# club_jersey_number                   -0.130320       -0.121486   0.004344
# national_rating                       0.128394        0.122457   0.004069
# national_jersey_number               -0.059912       -0.062660  -0.103960
# crossing                              0.444515        0.427843  -0.674405
# finishing                            -0.010770       -0.047173  -0.596976
# heading_accuracy                      0.573630        0.548260  -0.758208
# short_passing                         0.551598        0.520706  -0.736915
# volleys                               0.087830        0.051867  -0.599779
# dribbling                             0.322949        0.297187  -0.764009
# curve                                 0.278603        0.251605  -0.615087
# freekick_accuracy                     0.288904        0.258821  -0.563173
# long_passing                          0.598619        0.574603  -0.607436
# ball_control                          0.435459        0.404714  -0.795784
# acceleration                          0.190580        0.185800  -0.616057
# sprint_speed                          0.206214        0.201434  -0.620943
# agility                               0.151013        0.140620  -0.540735
# reactions                             0.265548        0.239461  -0.073362
# balance                               0.175627        0.174937  -0.516353
# shot_power                            0.271705        0.237734  -0.660624
# jumping                               0.270599        0.271647  -0.205964
# stamina                               0.581537        0.557913  -0.720161
# strength                              0.333000        0.305082  -0.115286
# long_shots                            0.192304        0.155519  -0.620318
# aggression                            0.747805        0.725244  -0.591955
# interceptions                         0.943039        0.930057  -0.497032
# positioning                           0.181509        0.150374  -0.691487
# vision                                0.160076        0.127915  -0.391047
# penalties                             0.119752        0.086446  -0.626277
# composure                             0.367660        0.334340  -0.398604
# marking                               0.911648        0.901281  -0.561245
# standing_tackle                       1.000000        0.975108  -0.542746
# sliding_tackle                        0.975108        1.000000  -0.522794
# GK_diving                            -0.542746       -0.522794   1.000000
# GK_handling                          -0.542166       -0.522268   0.971478
# GK_kicking                           -0.543875       -0.524117   0.967205
# GK_positioning                       -0.538760       -0.518450   0.971143
# GK_reflexes                          -0.543186       -0.522896   0.974499
# value                                 0.111844        0.091977  -0.027885
#
#                                GK_handling  GK_kicking  GK_positioning  \
# id                               -0.109114   -0.105234       -0.117351
# age                               0.103480    0.102583        0.114369
# height_cm                         0.300823    0.295080        0.299882
# weight_kgs                        0.346405    0.343403        0.348722
# overall_rating                   -0.032872   -0.037058       -0.024434
# potential                        -0.062007   -0.066899       -0.059544
# wage                             -0.030017   -0.032902       -0.030790
# international_reputation(1-5)     0.001284   -0.002429        0.003714
# weak_foot(1-5)                   -0.241911   -0.238251       -0.238978
# skill_moves(1-5)                 -0.629454   -0.625947       -0.627040
# release_clause_euro              -0.028872   -0.030143       -0.027136
# club_rating                       0.028320    0.023657        0.030666
# club_jersey_number                0.002400    0.002224       -0.000913
# national_rating                   0.007328    0.009551        0.008270
# national_jersey_number           -0.110322   -0.122334       -0.112888
# crossing                         -0.672657   -0.671151       -0.671881
# finishing                        -0.596522   -0.590509       -0.592971
# heading_accuracy                 -0.756180   -0.754469       -0.751747
# short_passing                    -0.735494   -0.731963       -0.731675
# volleys                          -0.599184   -0.593998       -0.595864
# dribbling                        -0.763170   -0.759273       -0.761086
# curve                            -0.613205   -0.609406       -0.612525
# freekick_accuracy                -0.561842   -0.558406       -0.560953
# long_passing                     -0.606049   -0.602985       -0.603305
# ball_control                     -0.794989   -0.791216       -0.791403
# acceleration                     -0.619321   -0.616337       -0.616149
# sprint_speed                     -0.624146   -0.621389       -0.620400
# agility                          -0.543624   -0.540389       -0.540956
# reactions                        -0.073664   -0.077013       -0.065896
# balance                          -0.519421   -0.515583       -0.516008
# shot_power                       -0.661607   -0.656401       -0.657473
# jumping                          -0.205158   -0.208143       -0.200988
# stamina                          -0.717850   -0.715167       -0.714803
# strength                         -0.114407   -0.115862       -0.107505
# long_shots                       -0.619537   -0.614421       -0.615372
# aggression                       -0.591277   -0.590519       -0.587294
# interceptions                    -0.496813   -0.498205       -0.492543
# positioning                      -0.690037   -0.685551       -0.687308
# vision                           -0.388309   -0.383887       -0.386292
# penalties                        -0.625767   -0.620169       -0.623162
# composure                        -0.396849   -0.395709       -0.389973
# marking                          -0.561508   -0.561162       -0.557115
# standing_tackle                  -0.542166   -0.543875       -0.538760
# sliding_tackle                   -0.522268   -0.524117       -0.518450
# GK_diving                         0.971478    0.967205        0.971143
# GK_handling                       1.000000    0.966851        0.970362
# GK_kicking                        0.966851    1.000000        0.966011
# GK_positioning                    0.970362    0.966011        1.000000
# GK_reflexes                       0.971368    0.967742        0.971177
# value                            -0.029630   -0.031366       -0.028329
#
#                                GK_reflexes     value
# id                               -0.104250 -0.142089
# age                               0.101886  0.081839
# height_cm                         0.299821  0.008243
# weight_kgs                        0.348003  0.047201
# overall_rating                   -0.031816  0.628308
# potential                        -0.061874  0.574187
# wage                             -0.031959  0.855451
# international_reputation(1-5)     0.000782  0.647245
# weak_foot(1-5)                   -0.242093  0.165213
# skill_moves(1-5)                 -0.631346  0.318331
# release_clause_euro              -0.029748  0.994198
# club_rating                       0.028827  0.535807
# club_jersey_number                0.006291 -0.091509
# national_rating                  -0.003388  0.582582
# national_jersey_number           -0.100907 -0.106326
# crossing                         -0.674769  0.249318
# finishing                        -0.596141  0.258215
# heading_accuracy                 -0.756509  0.186617
# short_passing                    -0.736798  0.327731
# volleys                          -0.598863  0.287304
# dribbling                        -0.764950  0.271276
# curve                            -0.614100  0.287912
# freekick_accuracy                -0.563051  0.266355
# long_passing                     -0.607370  0.305761
# ball_control                     -0.796539  0.307369
# acceleration                     -0.618617  0.173368
# sprint_speed                     -0.623275  0.175793
# agility                          -0.543570  0.199083
# reactions                        -0.072096  0.545531
# balance                          -0.519476  0.118970
# shot_power                       -0.660948  0.282272
# jumping                          -0.203908  0.135293
# stamina                          -0.719930  0.217627
# strength                         -0.112060  0.141402
# long_shots                       -0.618930  0.282767
# aggression                       -0.591659  0.189271
# interceptions                    -0.497615  0.144579
# positioning                      -0.691111  0.261171
# vision                           -0.391424  0.362123
# penalties                        -0.624938  0.243880
# composure                        -0.398835  0.453408
# marking                          -0.561445  0.138631
# standing_tackle                  -0.543186  0.111844
# sliding_tackle                   -0.522896  0.091977
# GK_diving                         0.974499 -0.027885
# GK_handling                       0.971368 -0.029630
# GK_kicking                        0.967742 -0.031366
# GK_positioning                    0.971177 -0.028329
# GK_reflexes                       1.000000 -0.030417
# value                            -0.030417  1.000000

# %%
feature_matrix=player_data.drop(['value'],axis=1)

# %%
#with the following function we can select highly correlated features
#it will remove the first feature that is correlated with anything other features
def correlation(corr_matrix,threshold):
    col_corr=set()
    
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>=threshold:
                colname=corr_matrix.columns[i] #getting the name of the column
                col_corr.add(colname)
    return col_corr

# %%
corr_matrix=feature_matrix.corr()
corr_features=correlation(corr_matrix,0.8)
print(len(set(corr_features)))
corr_features
# Out:
# 22
# {'GK_handling',
#  'GK_kicking',
#  'GK_positioning',
#  'GK_reflexes',
#  'agility',
#  'ball_control',
#  'curve',
#  'dribbling',
#  'freekick_accuracy',
#  'long_passing',
#  'long_shots',
#  'marking',
#  'penalties',
#  'positioning',
#  'reactions',
#  'release_clause_euro',
#  'short_passing',
#  'shot_power',
#  'sliding_tackle',
#  'sprint_speed',
#  'standing_tackle',
#  'volleys'}

# %%
corr_categories_features=correlation(categories_corr,1.0)
print(len(set(corr_categories_features)))
corr_categories_features
# Out:
# 16
# {'CAM',
#  'CB',
#  'CDM',
#  'CF',
#  'CM',
#  'RAM',
#  'RB',
#  'RCB',
#  'RCM',
#  'RDM',
#  'RF',
#  'RM',
#  'RS',
#  'RW',
#  'RWB',
#  'ST'}

# %%
df=data.copy()

data.drop(['id','name','full_name','birth_date','height_cm','nationality'],axis=1,inplace=True)
data.drop(corr_features,axis=1,inplace=True)
data.drop(corr_categories_features,axis=1,inplace=True)
print(data.shape)
# Out:
# (14363, 39)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14363 entries, 0 to 14362
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            14363 non-null  int64
#  1   weight_kgs                     14363 non-null  float64
#  2   overall_rating                 14363 non-null  int64
#  3   potential                      14363 non-null  int64
#  4   wage                           14363 non-null  float64
#  5   international_reputation(1-5)  14363 non-null  int64
#  6   weak_foot(1-5)                 14363 non-null  int64
#  7   skill_moves(1-5)               14363 non-null  int64
#  8   work_rate                      14363 non-null  int64
#  9   body_type                      14363 non-null  int64
#  10  club_rating                    14363 non-null  float64
#  11  years_player_club              14363 non-null  int32
#  12  national_rating                14363 non-null  float64
#  13  crossing                       14363 non-null  int64
#  14  finishing                      14363 non-null  int64
#  15  heading_accuracy               14363 non-null  int64
#  16  acceleration                   14363 non-null  int64
#  17  balance                        14363 non-null  int64
#  18  jumping                        14363 non-null  int64
#  19  stamina                        14363 non-null  int64
#  20  strength                       14363 non-null  int64
#  21  aggression                     14363 non-null  int64
#  22  interceptions                  14363 non-null  int64
#  23  vision                         14363 non-null  int64
#  24  composure                      14363 non-null  int64
#  25  GK_diving                      14363 non-null  int64
#  26  LS                             14363 non-null  float64
#  27  LW                             14363 non-null  float64
#  28  LF                             14363 non-null  float64
#  29  LAM                            14363 non-null  float64
#  30  LM                             14363 non-null  float64
#  31  LCM                            14363 non-null  float64
#  32  LWB                            14363 non-null  float64
#  33  LDM                            14363 non-null  float64
#  34  LB                             14363 non-null  float64
#  35  LCB                            14363 non-null  float64
#  36  Left                           14363 non-null  float64
#  37  Right                          14363 non-null  float64
#  38  value                          14363 non-null  float64
# dtypes: float64(17), int32(1), int64(21)
# memory usage: 4.2 MB

# %%
X=data.iloc[:,0:len(data.iloc[0,:])-1]#features
Y=data.iloc[:,-1]#label

# %%
#feature scaling
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
joblib.dump(scaler,'scaler')
X.head()
# Out:
#         age  weight_kgs  overall_rating  potential      wage  \
# 0  0.321429    0.398010        0.361702   0.361702  0.000000
# 1  0.535714    0.495854        0.531915   0.510638  0.022026
# 2  0.250000    0.300166        0.510638   0.638298  0.019824
# 3  0.500000    0.548922        0.531915   0.510638  0.070485
# 4  0.250000    0.412935        0.361702   0.489362  0.000000
#
#    international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  work_rate  \
# 0                           0.00             0.5              0.50      0.875
# 1                           0.25             0.5              0.25      0.125
# 2                           0.00             0.5              0.50      0.875
# 3                           0.00             0.5              0.50      1.000
# 4                           0.00             0.5              0.25      0.250
#
#    body_type  club_rating  years_player_club  national_rating  crossing  \
# 0        0.5      0.28125           0.086957         0.000000  0.556818
# 1        0.0      0.59375           0.000000         0.000000  0.193182
# 2        0.0      0.50000           0.130435         0.870588  0.488636
# 3        0.5      0.56250           0.347826         0.000000  0.693182
# 4        0.0      0.31250           0.130435         0.000000  0.625000
#
#    finishing  heading_accuracy  acceleration  balance   jumping   stamina  \
# 0   0.630435          0.422222      0.858824   0.8000  0.342466  0.482353
# 1   0.152174          0.800000      0.376471   0.4875  0.863014  0.211765
# 2   0.760870          0.700000      0.952941   0.8625  0.657534  0.752941
# 3   0.554348          0.711111      0.635294   0.4875  0.657534  0.823529
# 4   0.369565          0.488889      0.682353   0.6750  0.671233  0.823529
#
#    strength  aggression  interceptions    vision  composure  GK_diving  \
# 0  0.532468    0.228916       0.516854  0.523810   0.542169   0.157303
# 1  0.740260    0.783133       0.719101  0.214286   0.746988   0.123596
# 2  0.584416    0.493976       0.280899  0.619048   0.662651   0.157303
# 3  0.727273    0.602410       0.764045  0.500000   0.542169   0.112360
# 4  0.519481    0.554217       0.584270  0.380952   0.445783   0.089888
#
#          LS        LW        LF       LAM        LM       LCM       LWB  \
# 0  0.019537  0.018757  0.016616  0.018209  0.015711  0.017427  0.033535
# 1  0.008740  0.009299  0.007573  0.011082  0.006653  0.007117  0.028663
# 2  0.062376  0.039044  0.055711  0.032017  0.037276  0.021156  0.026737
# 3  0.025238  0.019008  0.016616  0.018209  0.021605  0.051858  0.097830
# 4  0.013423  0.006906  0.010899  0.010726  0.010807  0.017427  0.031884
#
#         LDM        LB       LCB  Left  Right
# 0  0.034108  0.022708  0.052094   0.0    1.0
# 1  0.026680  0.021029  0.086960   0.0    1.0
# 2  0.025268  0.035277  0.043031   0.0    1.0
# 3  0.063281  0.078284  0.070823   1.0    0.0
# 4  0.031754  0.020493  0.018741   0.0    1.0

# %%
#split data int train 80%  test 20%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20,shuffle=True,random_state=10)

print(X_train.shape)
print(X_test.shape)
# Out:
# (11490, 38)
# (2873, 38)

# %% [markdown]
# **Apply   polynomial/Normal/Regularized   regression model**

# %%
import time
def model_trial(X_train, X_test, y_train, y_test, model, degree=30):
    start=time.time()
    poly_features = PolynomialFeatures(degree=degree)
    X_train_poly = poly_features.fit_transform(X_train)

    model.fit(X_train_poly, y_train)

    y_train_predicted = model.predict(X_train_poly)
    prediction = model.predict(poly_features.fit_transform(X_test))

    train_err = metrics.mean_squared_error(y_train, y_train_predicted)
    test_err = metrics.mean_squared_error(y_test, prediction)
    end=time.time()
    print('Train subset (RMSE) for degree {}: '.format(degree), np.sqrt(train_err))
    print('test subset (RMSE) for degree {}: '.format(degree), np.sqrt(test_err))
    print('Train data Accuracy',model.score(X_train_poly,y_train))
    print('Test data Accuracy',model.score(poly_features.fit_transform(X_test),y_test))
    print(f"Training time:{end - start}s")

# %%
import time
import joblib

def model_trial_R(X_train, X_test, y_train, y_test, model, degree=30):
    start=time.time()
    poly_features = PolynomialFeatures(degree=degree)
    X_train_poly = poly_features.fit_transform(X_train)

    model.fit(X_train_poly, y_train)

    y_train_predicted = model.predict(X_train_poly)




    prediction = model.predict(poly_features.fit_transform(X_test))

    train_err = metrics.mean_squared_error(y_train, y_train_predicted)
    test_err = metrics.mean_squared_error(y_test, prediction)
    end=time.time()
    print('Train subset (RMSE) for degree {}: '.format(degree), np.sqrt(train_err))
    print('test subset (RMSE) for degree {}: '.format(degree), np.sqrt(test_err))
    print('Train data Accuracy',model.score(X_train_poly,y_train))
    print('Test data Accuracy',model.score(poly_features.fit_transform(X_test),y_test))
    print(f"Training time:{end - start}s")

# %%
def cross_validation(X_train, y_train, model,Cfold=10, degree=30):
    poly_features = PolynomialFeatures(degree=degree)
    # transforms the existing features to higher degree features.
    X_train_poly = poly_features.fit_transform(X_train)
    # fit the transformed features to Linear Regression
    scores = cross_val_score(model, X_train_poly, y_train, scoring='neg_mean_squared_error', cv=Cfold)
    model_2_score = abs(scores.mean())
    model.fit(X_train_poly, y_train)

    print("cross validation score is ",np.sqrt(model_2_score))

# %%
#tuning degree of polynomial regression
print("polynomial_model of degree 1 with cross validation")
cross_validation(X_train, y_train ,linear_model.LinearRegression(),10,1)
print("polynomial_model of degree 2 with cross validation")
cross_validation(X_train, y_train ,linear_model.LinearRegression(),10,2)
# Out:
# polynomial_model of degree 1 with cross validation
# cross validation score is  1875752.765098274
# polynomial_model of degree 2 with cross validation
# cross validation score is  1247836.0534200782

# %%
# best model with degree 2
print("polynomial model")
model_trial(X_train, X_test, y_train, y_test ,linear_model.LinearRegression(),2)
# Out:
# polynomial model
# Train subset (RMSE) for degree 2:  535036.2352122045
# test subset (RMSE) for degree 2:  1381556.7171111035
# Train data Accuracy 0.9903332838022798
# Test data Accuracy 0.9559979489547514
# Training time:1.4557209014892578s

# %%
#tune degree with redge model
print('Ridge model')
cross_validation(X_train, y_train, linear_model.Ridge(),10,1)
cross_validation(X_train, y_train, linear_model.Ridge(),10,2)
cross_validation(X_train, y_train, linear_model.Ridge(),5,3)
# Out:
# Ridge model
# cross validation score is  1876072.5767333717
# cross validation score is  1048677.7554352267
# cross validation score is  897696.5308909385

# %%
#tuning alpha for ridge regression model using GridSearchCV

from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
poly_features = PolynomialFeatures(degree=2)
X_train_poly = poly_features.fit_transform(X_train)
ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X_train_poly,y_train)

print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 0.01}
# -933216071788.1676

# %%
# best model with degree 2 and alpha=0.01
print("Ridge model")
model_trial_R(X_train, X_test, y_train, y_test ,linear_model.Ridge(alpha=0.01),2)
# Out:
# Ridge model
# Train subset (RMSE) for degree 2:  566836.6240935553
# test subset (RMSE) for degree 2:  1265269.717106255
# Train data Accuracy 0.9891500338537255
# Test data Accuracy 0.963093597773523
# Training time:0.6220986843109131s
